# %%
# %load_ext autoreload
# %autoreload 2 
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
import matplotlib
plt.rcParams["figure.figsize"] = [12,6.75]
plt.style.use('ggplot')
import pandas as pd
import numpy as np 
import pickle as pk

# %%
font = {'family' : 'normal',
       'weight' : 'normal',
        'size'   : 30}

matplotlib.rc('font', **font)

# %%
downloads_path = '/Users/dbcerigo/Downloads/'

# %%
plt.scatter([0,-0.5,-0.2,0.1,0.8],[0,0,0,1,1], s=400)
plt.xlabel('x')
plt.ylabel('y')
axes = plt.gca()
axes.set_xlim([-1,1])
plt.tight_layout()
plt.savefig(downloads_path + 'dannetv2_data.png')
# Out:
# /Users/dbcerigo/miniconda3/envs/basePy3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.scatter([-0.2,0.1,0.3,0.4,0.8],[0,0,0,1,1], s=400)
plt.xlabel('x')
plt.ylabel('y')
axes = plt.gca()
axes.set_xlim([-1,1])
plt.tight_layout()c
plt.savefig(downloads_path + 'dannetv3_data.png')
# Out:
# /Users/dbcerigo/miniconda3/envs/basePy3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.plot([-1,0,0.000001,1],[0,0,1,1], )
plt.xlabel('x')
plt.ylabel('y')
plt.tight_layout()
plt.savefig(downloads_path + 'step1.png')
# Out:
# /Users/dbcerigo/miniconda3/envs/basePy3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.scatter([0.2,0.4,0.3,0.1,0.7,0.8],[0.6,0.9,0.1,0.2,0.2,0.4], s=400, marker='x')
plt.scatter([0.55,0.7,0.9,0.8,0.55],[0.55,0.59,0.71,0.82,0.9], s=400, marker='o')


plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
axes = plt.gca()
axes.set_xlim([0,1])
axes.set_ylim([0,1])
plt.tight_layout()
plt.savefig(downloads_path + 'dannetv4_data.png')
# Out:
# /Users/dbcerigo/miniconda3/envs/basePy3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.scatter([0,1,2,3],[4,7,7,8], s=400)
plt.xlabel('x')
plt.ylabel('y')
axes = plt.gca()
plt.tight_layout()
plt.savefig(downloads_path + 'dannetv6_data.png')
# Out:
# /Users/dbcerigo/miniconda3/envs/basePy3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
